# %%
from selenium import webdriver
from save_images import make_directory, save_images, save_data_to_csv
from scrap_image import scrap_image_url
from selenium.common.exceptions import StaleElementReferenceException
import os

# %%
#step1
CDriver="D:\\Drivers"
lists=['saree','tshirt','shirt']

# %%
#step2
def make_directory(dirname):
    current_path=os.getcwd()
    path=os.path.join(current_path,dirname)
    if not os.path.exists(path):
        os.makedirs(path)

# %%
def scrap_images(app):
    url=[]
    images=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']//img")
    for image in images:
        source = image.get_attribute('src')
        url.append(source)
        print(source)
    return url

# %%
#step4
import shutil
import requests
def save_images(category,data):
    if(category=='saree'):
        for index, link in enumerate(data):
            print("Downloading {0} of {1}images".format(index+1, len(data)))
            response=requests.get(link)
            with open('D:/Amazon/saree/img_{0}.jpeg'.format(index), "wb") as file:
                file.write(response.content)
    elif(category=='tshirt'):
        for index, link in enumerate(data):
            print("Downloading {0} of {1}images".format(index+1, len(data)))
            response=requests.get(link)
            with open('D:/Amazon/tshirt/img_{0}.jpeg'.format(index), "wb") as file:
                file.write(response.content)
    else:
        for index, link in enumerate(data):
            print("Downloading {0} of {1}images".format(index+1, len(data)))
            response=requests.get(link)
            with open('D:/Amazon/shirt/img_{0}.jpeg'.format(index), "wb") as file:
                file.write(response.content)

# %%
for category in lists:
    driver=webdriver.Chrome(executable_path=r'D:/Drivers/chromedriver.exe')
    driver.maximize_window()
    if(category=='saree'):
        app_url=driver.get("https://www.amazon.in/s?k=saree&ref=nb_sb_noss_2")
        make_directory("D:\\Amazon\\saree")
        for i in range(1,3):
            data=scrap_images(app_url)
            save_images(category,data)
            
            driver.close()
    elif(category=='tshirt'):
        app_url=driver.get("https://www.amazon.in/s/ref=nb_sb_noss_2?url=search-alias%3Daps&field-keywords=tshirt")
        make_directory("D:\\Amazon\\tshirt")
        data=scrap_images(app_url)
        save_images(category,data)
        driver.close()
    else:
        app_url=driver.get("https://www.amazon.in/s?k=shirt&ref=nb_sb_noss_2")
        make_directory("D:\\Amazon\\shirt")
        data=scrap_images(app_url)
        save_images(category,data)
        driver.close()
# Out:
# https://m.media-amazon.com/images/I/81Eiqt5ab3L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71gS9nADNeL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61EvPLNdVBL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81-uuEDvnQL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81KHEluucGL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81IR4+b+jRL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81O-J6qiXvL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91BMuw+xVkL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/910KJPiGcYL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/6145npqbg4L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91Nfpvp1yhL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91YFGHzjm4L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91ZdosKaqbL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71p0MOTaZ3L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81Go-YQRDwL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/810Kq7xQvtL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61fu2EnscfL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81wCS9fycmL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91yPghSgR8L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61xiCTgjAnL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71LZF0v4o8L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81QhclXBeEL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71y-fzR6gAL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81Ac5LasV-L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91YhxRLNTuL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71iSbIrFzcL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71somdYFw+L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71H+wwqqLvL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71-fmGvNgSL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81gd-OX-EmL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81zQm4+FtKL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/7131rf2-t6L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81et7nKmZHL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81ujgS5lKqL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81JxWA-m4SL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/61eRq0YtC+L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71F3yhGwoWL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71TPLQLP0qL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71b5JqOaJcL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81G+ou9wplL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71evG0zPauL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91qr5nl9kIL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81uSvaWKNtL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91+auNsyHVL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81u+myDumdL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81Q9ig3qklL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/81j-y-KWb6L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/813pXo6Pu7L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/916ROGKpL1L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91Pc9HRArSL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91RS1ozop+L._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/91MTkoNHToL._AC_UL320_.jpg
# https://m.media-amazon.com/images/I/71L5PHo+9sL._AC_UL320_.jpg
# Downloading 1 of 53images
# Downloading 2 of 53images
# Downloading 3 of 53images
# Downloading 4 of 53images
# Downloading 5 of 53images
# Downloading 6 of 53images
# Downloading 7 of 53images
# Downloading 8 of 53images
# Downloading 9 of 53images
# Downloading 10 of 53images
# Downloading 11 of 53images
# Downloading 12 of 53images
# Downloading 13 of 53images
# Downloading 14 of 53images
# Downloading 15 of 53images
# Downloading 16 of 53images
# Downloading 17 of 53images
# Downloading 18 of 53images
# Downloading 19 of 53images
# Downloading 20 of 53images
# Downloading 21 of 53images
# Downloading 22 of 53images
# Downloading 23 of 53images
# Downloading 24 of 53images
# Downloading 25 of 53images
# Downloading 26 of 53images
# Downloading 27 of 53images
# Downloading 28 of 53images
# Downloading 29 of 53images
# Downloading 30 of 53images
# Downloading 31 of 53images
# Downloading 32 of 53images
# Downloading 33 of 53images
# Downloading 34 of 53images
# Downloading 35 of 53images
# Downloading 36 of 53images
# Downloading 37 of 53images
# Downloading 38 of 53images
# Downloading 39 of 53images
# Downloading 40 of 53images
# Downloading 41 of 53images
# Downloading 42 of 53images
# Downloading 43 of 53images
# Downloading 44 of 53images
# Downloading 45 of 53images
# Downloading 46 of 53images
# Downloading 47 of 53images
# Downloading 48 of 53images
# Downloading 49 of 53images
# Downloading 50 of 53images
# Downloading 51 of 53images
# Downloading 52 of 53images
# Downloading 53 of 53images
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-6-119013a3b928> in <module>
#       8             data=scrap_images(app_url)
#       9             save_images(category,data)
# ---> 10             strNextBtn=driver.find_element_by_class_name('a_last').click()
#      11             driver.close()
#      12     elif(category=='tshirt'):
#
# ~\anaconda3\envs\Virtual\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# ~\anaconda3\envs\Virtual\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~\anaconda3\envs\Virtual\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\envs\Virtual\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".a_last"}
#   (Session info: chrome=83.0.4103.116)

# %%
#step3
#images=driver.find_elements_by_xpath("//div[@class='a-section aok-relative s-image-tall-aspect']//img")
